# %%
import theano
import nltk
import tensorflow
import keras
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot(np.random.rand(100,1))
